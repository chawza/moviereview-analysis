# %%
import pandas as pd
train = pd.read_csv('dataset/train.tsv', '\t')
train.head(5)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# ## Text Preprocessing

# %%
from pycontractions import Contractions
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

def preprocessing(sentences):
    cont = Contractions()
    wordnet = WordNetLemmatizer()
    stopword = stopwords.words('english')

    processed_input = []

    #iterate each review and preprocess each of them
    for each in sentences:
        sentence = each
        #lowercase casting
        sentence = sentence.lower()

        #tokenize
        sentence = sentence.split()

        #remove punctuation
        sentence = [x for x in sentence if x.isalpha()]

        #stemming
        sentence = [wordnet.lemmatize(x) for x in sentence]

        #remove stop words
        filteredwords = []
        for word in sentence:
            if word not in stopword:
                filteredwords.append(word)

        processed_input.append(filteredwords)
    
    return processed_input

# %% [markdown]
# ## Convert the data

# %%
#train_phrase = train.Phrase
train_sentiment = train.Sentiment[:100]
train_phrase = train.Phrase[:100]

processed_phrase = preprocessing(train_phrase)
 
processed_phrase = pd.DataFrame(data=processed_phrase)

#fill empty column
import numpy as np
length = processed_phrase.shape[1]
for i in range(255-length):
    processed_phrase[length + i] = None

processed_phrase
# Out:
#         0         1              2      3     4      5     6     7       8    \
# 0    series  escapade  demonstrating  adage  good  goose  also  good  gander
# 1    series  escapade  demonstrating  adage  good  goose  None  None    None
# 2    series      None           None   None  None   None  None  None    None
# 3      None      None           None   None  None   None  None  None    None
# 4    series      None           None   None  None   None  None  None    None
# ..      ...       ...            ...    ...   ...    ...   ...   ...     ...
# 95  suspect      None           None   None  None   None  None  None    None
# 96  suspect      None           None   None  None   None  None  None    None
# 97  suspect      None           None   None  None   None  None  None    None
# 98     None      None           None   None  None   None  None  None    None
# 99  suspect      None           None   None  None   None  None  None    None
#
#              9    ...   245   246   247   248   249   250   251   252   253  \
# 0   occasionally  ...  None  None  None  None  None  None  None  None  None
# 1           None  ...  None  None  None  None  None  None  None  None  None
# 2           None  ...  None  None  None  None  None  None  None  None  None
# 3           None  ...  None  None  None  None  None  None  None  None  None
# 4           None  ...  None  None  None  None  None  None  None  None  None
# ..           ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 95          None  ...  None  None  None  None  None  None  None  None  None
# 96          None  ...  None  None  None  None  None  None  None  None  None
# 97          None  ...  None  None  None  None  None  None  None  None  None
# 98          None  ...  None  None  None  None  None  None  None  None  None
# 99          None  ...  None  None  None  None  None  None  None  None  None
#
#      254
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# ..   ...
# 95  None
# 96  None
# 97  None
# 98  None
# 99  None
#
# [100 rows x 255 columns]

# %% [markdown]
# ## Create the model

# %%
from sklearn.naive_bayes import MultinomialNB

classfier = MultinomialNB()
classfier.fit(processed_phrase,train_sentiment)

print("Accuracy: ", classfier.score(preprocessing, train_sentiment))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c7af60d7fe19> in <module>
#       2
#       3 classfier = MultinomialNB()
# ----> 4 classfier.fit(processed_phrase,train_sentiment)
#       5
#       6 print("Accuracy: ", classfier.score(preprocessing, train_sentiment))
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     586         self : object
#     587         """
# --> 588         X, y = check_X_y(X, y, 'csr')
#     589         _, n_features = X.shape
#     590
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     534         # make sure we actually converted to numeric:
#     535         if dtype_numeric and array.dtype.kind == "O":
# --> 536             array = array.astype(np.float64)
#     537         if not allow_nd and array.ndim >= 3:
#     538             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'series'
